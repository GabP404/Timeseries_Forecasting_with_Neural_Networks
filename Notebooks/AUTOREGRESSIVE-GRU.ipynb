# %% [markdown]
# # **PARAMS**

# %%
WINDOW_SIZE = 200
STRIDE_SIZE = 10
TELESCOPE_SIZE = 18

TEST_QUOTA = 0.2
VALIDATION_QUOTA = 0.15

EPOCHS = 250
BATCH_SIZE = 256

MODEL_NAME = "AUTOREGRESSIVE-GRU"

# %% [markdown]
# # **Import libraries**

# %%
# Fix randomness and hide warnings
seed = 42

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['PYTHONHASHSEED'] = str(seed)
os.environ['MPLCONFIGDIR'] = os.getcwd()+'/configs/'

from datetime import date

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

import numpy as np
np.random.seed(seed)

import logging

import random
random.seed(seed)

import math

# Import tensorflow
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)
print(tf.__version__)

import pandas as pd
import seaborn as sns
from datetime import datetime
import matplotlib.pyplot as plt
plt.rc('font', size=16)
from sklearn.preprocessing import MinMaxScaler
# Out:
# 2.16.1

# %% [markdown]
# # **Load the Dataset**

# %%
pwd
# Out:
# '/kaggle/working'

# %%
def load_dataset():
    training_data = np.load("/kaggle/input/timeseries/training_data.npy")
    print(f"Training shape: {training_data.shape}")

    categories = np.load("/kaggle/input/timeseries/categories.npy")
    print(f"Categories shape: { categories.shape}" )

    valid_periods = np.load("/kaggle/input/timeseries/valid_periods.npy")
    print(f"Valid_periods shape: { valid_periods.shape}")

    return training_data, categories, valid_periods

# %%
training_data, categories, valid_periods = load_dataset()
# Out:
# Training shape: (48000, 2776)
# Categories shape: (48000,)
# Valid_periods shape: (48000, 2)

# %%
lengths = valid_periods[:,1] - valid_periods[:,0]

# %%
df = pd.DataFrame()
df["Lengths"] = lengths
df["Categories"] = categories

# %%
def plotDataLengths(df):

  plt.figure(figsize=(17,4))

  plt.scatter(df["Lengths"], df["Categories"])

  plt.show()

# %%
plotDataLengths(df)

# %%
del df
del lengths

# %%
df = pd.DataFrame(training_data)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48000 entries, 0 to 47999
# Columns: 2776 entries, 0 to 2775
# dtypes: float64(2776)
# memory usage: 1016.6 MB

# %%
def getSequenceFromDataset(index):
  return training_data[index,valid_periods[index][0] : valid_periods[index][1]]

# %%
getSequenceFromDataset(0)
# Out:
# array([0.49166667, 0.52407407, 0.54444444, 0.46388889, 0.40648148,
#        0.35462963, 0.31296296, 0.36666667, 0.38333333, 0.27962963,
#        0.23796296, 0.25740741, 0.47962963, 0.43240741, 0.53518519,
#        0.48055556, 0.37592593, 0.38611111, 0.32685185, 0.36666667,
#        0.25555556, 0.23981481, 0.21111111, 0.26481481, 0.46851852,
#        0.46944444, 0.41666667, 0.43981481, 0.36111111, 0.32592593,
#        0.30740741, 0.34259259, 0.28611111, 0.2787037 , 0.18425926,
#        0.21111111, 0.38518519, 0.375     , 0.44444444, 0.32962963,
#        0.38981481, 0.29444444, 0.27037037, 0.33518519, 0.31666667,
#        0.31481481, 0.28888889, 0.31203704, 0.39444444, 0.475     ,
#        0.51666667, 0.47685185, 0.47777778, 0.37222222, 0.32685185,
#        0.43888889, 0.35833333, 0.40648148, 0.36944444, 0.38981481,
#        0.55462963, 0.53333333, 0.5537037 , 0.53518519, 0.48333333,
#        0.50462963, 0.42777778, 0.4787037 , 0.46666667, 0.42962963,
#        0.43888889, 0.41296296, 0.55833333, 0.52314815, 0.56944444,
#        0.56388889, 0.51481481, 0.50833333, 0.45185185, 0.61018519,
#        0.60462963, 0.59722222, 0.57962963, 0.54166667, 0.61759259,
#        0.6537037 , 0.60925926, 0.55555556, 0.51018519, 0.45555556,
#        0.41388889, 0.51759259, 0.43333333, 0.41111111, 0.38425926,
#        0.42314815, 0.43888889, 0.48703704, 0.47222222, 0.5       ,
#        0.44351852, 0.3712963 , 0.36666667, 0.39537037, 0.34444444,
#        0.33518519, 0.3       , 0.30462963, 0.37407407, 0.43703704,
#        0.41759259, 0.39537037, 0.3787037 , 0.28055556, 0.31018519,
#        0.30555556, 0.32592593, 0.34907407, 0.25925926, 0.28703704,
#        0.33888889, 0.32777778, 0.30092593, 0.34351852, 0.36296296,
#        0.29166667, 0.2462963 , 0.3212963 , 0.33055556, 0.28425926,
#        0.25555556, 0.2462963 , 0.32777778, 0.35462963, 0.42037037,
#        0.35277778, 0.32777778, 0.30277778, 0.21111111, 0.2462963 ,
#        0.19907407, 0.18703704, 0.18333333, 0.18333333, 0.23148148,
#        0.28796296, 0.31759259, 0.22685185, 0.18333333, 0.13888889,
#        0.16111111, 0.19907407, 0.18240741, 0.1537037 , 0.15740741,
#        0.19444444, 0.26111111, 0.28425926, 0.28611111, 0.25740741,
#        0.21574074, 0.19259259, 0.15185185, 0.15185185, 0.1462963 ,
#        0.10462963, 0.07962963, 0.15740741, 0.28425926, 0.30925926,
#        0.31944444, 0.29074074, 0.25277778, 0.2287037 , 0.1787037 ,
#        0.25277778, 0.26944444, 0.29907407, 0.23148148, 0.27314815,
#        0.2787037 , 0.31666667, 0.42592593, 0.42314815, 0.40277778,
#        0.31574074, 0.31666667, 0.40740741, 0.40555556, 0.32037037,
#        0.27222222, 0.32592593, 0.42222222, 0.44351852, 0.45277778,
#        0.45555556, 0.3037037 , 0.40833333, 0.31574074, 0.40277778,
#        0.40462963, 0.33148148, 0.27592593, 0.26944444, 0.41666667,
#        0.4537037 , 0.42777778, 0.30185185, 0.32685185, 0.27685185,
#        0.25555556, 0.41388889, 0.31666667, 0.39351852, 0.275     ,
#        0.28518519, 0.4962963 , 0.44074074, 0.50925926, 0.36111111,
#        0.29907407, 0.1787037 , 0.24351852, 0.31203704, 0.24166667,
#        0.21574074, 0.21481481, 0.18055556, 0.39722222, 0.31481481,
#        0.39907407, 0.24814815, 0.23518519, 0.22685185, 0.17407407,
#        0.24722222, 0.24166667, 0.18055556, 0.18981481, 0.23703704,
#        0.33888889, 0.38611111, 0.33981481, 0.275     , 0.23888889,
#        0.20555556, 0.2287037 , 0.2712963 , 0.23055556, 0.18425926,
#        0.10833333, 0.11111111, 0.33796296, 0.32592593, 0.31574074,
#        0.21203704, 0.14537037, 0.11296296, 0.07962963, 0.18425926,
#        0.13240741, 0.18981481, 0.03796296, 0.1037037 , 0.18703704,
#        0.2787037 , 0.21759259, 0.16666667, 0.11481481, 0.075     ,
#        0.05833333, 0.15833333, 0.13888889, 0.09074074, 0.10092593,
#        0.15185185, 0.2537037 , 0.27037037, 0.21574074, 0.12962963,
#        0.09166667, 0.05555556, 0.06203704, 0.14907407, 0.12962963,
#        0.03888889, 0.        , 0.09351852, 0.30925926, 0.25555556,
#        0.29074074, 0.1287037 , 0.11296296, 0.10648148, 0.08888889,
#        0.17962963, 0.02685185, 0.07962963, 0.09259259, 0.08518519,
#        0.23703704, 0.25833333, 0.25092593, 0.15648148, 0.14814815,
#        0.13981481, 0.13888889, 0.20092593, 0.2212963 , 0.19259259,
#        0.16481481, 0.19907407, 0.27037037, 0.34814815, 0.30277778,
#        0.24166667, 0.21296296, 0.18425926, 0.16388889, 0.27962963,
#        0.19814815, 0.23796296, 0.15833333, 0.19351852, 0.40277778,
#        0.44444444, 0.44074074, 0.26574074, 0.21388889, 0.25277778,
#        0.2287037 , 0.22407407, 0.20462963, 0.24166667, 0.15185185,
#        0.18425926, 0.28796296, 0.43703704, 0.37685185, 0.27685185,
#        0.27037037, 0.22685185, 0.21296296, 0.26481481, 0.18796296,
#        0.18425926, 0.19351852, 0.17037037, 0.38148148, 0.38333333,
#        0.36574074, 0.27685185, 0.21574074, 0.20833333, 0.11481481,
#        0.17407407, 0.18796296, 0.17777778, 0.13425926, 0.14814815,
#        0.28611111, 0.36111111, 0.30185185, 0.11759259, 0.14351852,
#        0.1212963 , 0.11666667, 0.19166667, 0.12592593, 0.13888889,
#        0.1287037 , 0.14722222, 0.28055556, 0.40277778, 0.39444444,
#        0.23703704, 0.20648148, 0.19722222, 0.16851852, 0.18703704,
#        0.09537037, 0.14444444, 0.0962963 , 0.17777778, 0.35648148,
#        0.46388889, 0.41851852, 0.28148148, 0.26203704, 0.23888889,
#        0.22407407, 0.35462963, 0.27222222, 0.30462963, 0.28333333,
#        0.40092593, 0.66851852, 0.7962963 , 0.78611111, 0.61018519,
#        0.47777778, 0.44351852, 0.48888889, 0.6287037 , 0.56574074,
#        0.56666667, 0.46296296, 0.46481481, 0.64537037, 0.85      ,
#        0.94722222, 0.75925926, 0.63055556, 0.62962963, 0.63055556,
#        0.75833333, 0.60925926, 0.57314815, 0.4712963 , 0.525     ,
#        0.89166667, 1.        , 0.92777778, 0.68888889, 0.60648148,
#        0.64351852, 0.57685185, 0.575     , 0.53611111, 0.47962963,
#        0.4787037 , 0.58333333, 0.75      , 0.84537037, 0.73148148,
#        0.62407407, 0.59074074, 0.51481481, 0.56018519, 0.59537037,
#        0.51759259, 0.4787037 , 0.41296296, 0.50185185, 0.75648148,
#        0.74444444, 0.64074074, 0.51666667, 0.60277778, 0.36759259,
#        0.33148148])

# %% [markdown]
# # **GET ONE HOT CATEGORIES**

# %%
categories
# Out:
# array(['D', 'D', 'D', ..., 'F', 'F', 'F'], dtype='<U1')

# %%
np.unique(categories)
# Out:
# array(['A', 'B', 'C', 'D', 'E', 'F'], dtype='<U1')

# %%
# Create a dictionary to map categories to numerical values
category_to_index = {category: index for index, category in enumerate(np.unique(categories))}
category_to_index
# Out:
# {'A': 0, 'B': 1, 'C': 2, 'D': 3, 'E': 4, 'F': 5}

# %%
# Convert labels to numerical values using the dictionary
numerical_labels = [category_to_index[label] for label in categories]
numerical_labels[:15]
# Out:
# [3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3]

# %%
one_hot_categories = tfk.utils.to_categorical(numerical_labels,len(np.unique(categories)))

# %%
one_hot_categories[-1]
# Out:
# array([0., 0., 0., 0., 0., 1.])

# %% [markdown]
# # **Some Plots**

# %%
def inspect_dataset(indexes):
    num_plots = len(indexes)
    fig, axs = plt.subplots(num_plots, 1, figsize=(10, 6*num_plots))

    for i, index in enumerate(indexes):


        sequence = getSequenceFromDataset(index)  # Slice the sequence using iloc

        if num_plots > 1:
            ax = axs[i]
        else:
            ax = axs  # If only one plot, axs is a single axis, not an array

        ax.set_title(f"Sequence {index}, Category {categories[index]}")
        ax.plot(sequence)  # Plot the entire sequence
        ax.set_xlabel("Time")
        ax.set_ylabel("Value")

    plt.tight_layout()
    plt.show()

# Call the function with the DataFrame and a list of indexes of the sequences you want to plot
inspect_dataset([3, 12500, 25000])  # Example: plotting sequences with indexes 3, 5, and 7

# %% [markdown]
# # **Normalize and Split the Dataset**

# %%
test_quota = TEST_QUOTA
test_quota
# Out:
# 0.2

# %%
from sklearn.model_selection import train_test_split

# Creating indices for splitting
indices = np.arange(len(training_data))

# Splitting indices into train and test indices
train_indices, test_indices = train_test_split(indices, test_size=test_quota, stratify=categories, random_state=seed)

# Extracting data based on the split indices
train_data = training_data[train_indices]
test_data = training_data[test_indices]
train_categories = categories[train_indices]
test_categories = categories[test_indices]
valid_periods_train = valid_periods[train_indices]
valid_periods_test = valid_periods[test_indices]

# %%
train_data.shape
# Out:
# (38400, 2776)

# %%
test_data.shape
# Out:
# (9600, 2776)

# %%
training_data.shape
# Out:
# (48000, 2776)

# %%
def getTrainSequenceFromDataset(index):
  return train_data[index,valid_periods_train[index][0] : valid_periods_train[index][1]]

def getTestSequenceFromDataset(index):
  return test_data[index,valid_periods_test[index][0] : valid_periods_test[index][1]]

# %%
getTrainSequenceFromDataset(0).shape[0]
# Out:
# 512

# %%
getTestSequenceFromDataset(0).shape[0]
# Out:
# 267

# %%
import matplotlib.pyplot as plt
index_to_plot = 100

# Assuming X_train_raw and X_test_raw are NumPy arrays
plt.figure(figsize=(17, 5))

# Plot X_train_raw in blue color
plt.plot(getTrainSequenceFromDataset(index_to_plot), label='Train sequence (normalized)', color='blue')


plt.title(f'SEQUENCE {index_to_plot}: Category: {train_categories[index_to_plot]}')
plt.legend()
plt.show()

# %% [markdown]
# # **Prepare the Data**

# %%
window = WINDOW_SIZE
stride = STRIDE_SIZE

# %%
future = train_data[:,-window:]

print(f"future has {future[123].shape} sequences")
# Out:
# future has (200,) sequences

# %%
future = np.expand_dims(future, axis=0)
future.shape
# Out:
# (1, 38400, 200)

# %%
def build_sequences(train=True, window=200, stride=20, telescope=100):
    # Sanity check to avoid runtime errors
    assert window % stride == 0
    dataset = []
    labels = []

    maxIndex = train_data.shape[0] if train==True else test_data.shape[0]

    for index in range(maxIndex):

      if train == True:
        sequence = getTrainSequenceFromDataset(index)
        temp_sequence = getTrainSequenceFromDataset(index).copy()
      else:
        sequence = getTestSequenceFromDataset(index)
        temp_sequence = getTestSequenceFromDataset(index).copy()

      temp_label = sequence.copy()

      padding_check = len(sequence)%window

      if(padding_check != 0):
        # Compute padding length
        padding_len = window - len(sequence)%window
        padding = np.zeros((padding_len), dtype='float32')
        temp_sequence = np.concatenate((padding,sequence))
        padding = np.zeros((padding_len), dtype='float32')
        temp_label = np.concatenate((padding,temp_label))
        assert len(temp_sequence) % window == 0

      for idx in np.arange(0,len(temp_sequence)-window-telescope,stride):
        dataset.append(temp_sequence[idx:idx+window])
        labels.append(temp_label[idx+window:idx+window+telescope])

      del sequence
      del temp_sequence
      del temp_label

    dataset = np.array(dataset)
    labels = np.array(labels)
    return dataset, labels

# %%
telescope = TELESCOPE_SIZE

# %% [markdown]
# # **FORECAST**

# %%
def build_model(input_shape, output_shape):

    # GRU and dense

    input_layer = tfkl.Input(shape=input_shape, name='Input')
    bilstm = tfkl.Bidirectional(tfkl.GRU(16, return_sequences=True))(input_layer)
    dropout = tfkl.Dropout(.3, seed=seed)(bilstm)
    bilstm = tfkl.Bidirectional(tfkl.GRU(16, return_sequences=False))(dropout)
    dropout = tfkl.Dropout(.3, seed=seed)(bilstm)

    dense1 = tfkl.Dense(32)(dropout)

    dense2 = tfkl.Dense(output_shape[-1], kernel_initializer = tfk.initializers.GlorotUniform(seed))(dense1)
    output_layer = tfkl.LeakyReLU()(dense2)


    # Connect input and output through the Model class
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name='model')

    # Compile the model
    model.compile(loss=tfk.losses.MeanSquaredError(), optimizer=tfk.optimizers.AdamW(), metrics=['mae'])

    # Return the model
    return model

# %% [markdown]
# # **Autoregressive**

# %%
autoregressive_telescope = 3
assert autoregressive_telescope < telescope

# %%
epochs = EPOCHS
batch_size = BATCH_SIZE

# %%
X_train, y_train = build_sequences(True,window, stride, autoregressive_telescope)

# %%
X_train = np.expand_dims(X_train, axis=-1)

# %%
input_shape = X_train.shape[1:]
output_shape = y_train.shape[1:]

# %%
model = build_model(input_shape, output_shape)
model.summary()
tfk.utils.plot_model(model, expand_nested=True, show_shapes=True)
# Out:
# Model: "model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Input (InputLayer)              │ (None, 200, 1)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, 200, 32)        │         1,824 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 200, 32)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (None, 32)             │         4,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │            99 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu (LeakyReLU)         │ (None, 3)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,779 (30.39 KB)
#  Trainable params: 7,779 (30.39 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model
history = model.fit(
    x = X_train,
    y = y_train,
    batch_size = batch_size,
    epochs = 250,
    validation_split=.1,
    callbacks = [
        tfk.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=15, restore_best_weights=True),
        tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min', patience=10, factor=0.1, min_lr=1e-5)
    ]
).history
# Out:
# Epoch 1/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 60s 36ms/step - loss: 0.0262 - mae: 0.1032 - val_loss: 0.0069 - val_mae: 0.0525 - learning_rate: 0.0010
# Epoch 2/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0088 - mae: 0.0656 - val_loss: 0.0068 - val_mae: 0.0525 - learning_rate: 0.0010
# Epoch 3/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0085 - mae: 0.0644 - val_loss: 0.0058 - val_mae: 0.0478 - learning_rate: 0.0010
# Epoch 4/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 35ms/step - loss: 0.0077 - mae: 0.0619 - val_loss: 0.0058 - val_mae: 0.0478 - learning_rate: 0.0010
# Epoch 5/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 35ms/step - loss: 0.0076 - mae: 0.0615 - val_loss: 0.0056 - val_mae: 0.0470 - learning_rate: 0.0010
# Epoch 6/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 35ms/step - loss: 0.0076 - mae: 0.0613 - val_loss: 0.0056 - val_mae: 0.0469 - learning_rate: 0.0010
# Epoch 7/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 35ms/step - loss: 0.0075 - mae: 0.0610 - val_loss: 0.0056 - val_mae: 0.0477 - learning_rate: 0.0010
# Epoch 8/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0073 - mae: 0.0605 - val_loss: 0.0050 - val_mae: 0.0440 - learning_rate: 0.0010
# Epoch 9/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 82s 35ms/step - loss: 0.0069 - mae: 0.0586 - val_loss: 0.0047 - val_mae: 0.0426 - learning_rate: 0.0010
# Epoch 10/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 35ms/step - loss: 0.0068 - mae: 0.0581 - val_loss: 0.0047 - val_mae: 0.0435 - learning_rate: 0.0010
# Epoch 11/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0067 - mae: 0.0577 - val_loss: 0.0047 - val_mae: 0.0424 - learning_rate: 0.0010
# Epoch 12/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 82s 36ms/step - loss: 0.0066 - mae: 0.0574 - val_loss: 0.0050 - val_mae: 0.0453 - learning_rate: 0.0010
# Epoch 13/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0063 - mae: 0.0555 - val_loss: 0.0047 - val_mae: 0.0430 - learning_rate: 0.0010
# Epoch 14/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0060 - mae: 0.0536 - val_loss: 0.0046 - val_mae: 0.0422 - learning_rate: 0.0010
# Epoch 15/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0059 - mae: 0.0529 - val_loss: 0.0047 - val_mae: 0.0434 - learning_rate: 0.0010
# Epoch 16/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 82s 36ms/step - loss: 0.0058 - mae: 0.0527 - val_loss: 0.0046 - val_mae: 0.0417 - learning_rate: 0.0010
# Epoch 17/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0058 - mae: 0.0525 - val_loss: 0.0045 - val_mae: 0.0417 - learning_rate: 0.0010
# Epoch 18/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0058 - mae: 0.0523 - val_loss: 0.0046 - val_mae: 0.0424 - learning_rate: 0.0010
# Epoch 19/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 82s 36ms/step - loss: 0.0058 - mae: 0.0522 - val_loss: 0.0047 - val_mae: 0.0424 - learning_rate: 0.0010
# Epoch 20/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0057 - mae: 0.0521 - val_loss: 0.0045 - val_mae: 0.0412 - learning_rate: 0.0010
# Epoch 21/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0057 - mae: 0.0519 - val_loss: 0.0046 - val_mae: 0.0425 - learning_rate: 0.0010
# Epoch 22/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0057 - mae: 0.0518 - val_loss: 0.0045 - val_mae: 0.0412 - learning_rate: 0.0010
# Epoch 23/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0057 - mae: 0.0518 - val_loss: 0.0045 - val_mae: 0.0416 - learning_rate: 0.0010
# Epoch 24/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0057 - mae: 0.0517 - val_loss: 0.0045 - val_mae: 0.0412 - learning_rate: 0.0010
# Epoch 25/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0056 - mae: 0.0516 - val_loss: 0.0044 - val_mae: 0.0410 - learning_rate: 0.0010
# Epoch 26/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0056 - mae: 0.0515 - val_loss: 0.0046 - val_mae: 0.0428 - learning_rate: 0.0010
# Epoch 27/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0056 - mae: 0.0515 - val_loss: 0.0045 - val_mae: 0.0416 - learning_rate: 0.0010
# Epoch 28/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0056 - mae: 0.0514 - val_loss: 0.0044 - val_mae: 0.0408 - learning_rate: 0.0010
# Epoch 29/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0056 - mae: 0.0512 - val_loss: 0.0044 - val_mae: 0.0404 - learning_rate: 0.0010
# Epoch 30/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0056 - mae: 0.0512 - val_loss: 0.0044 - val_mae: 0.0409 - learning_rate: 0.0010
# Epoch 31/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0055 - mae: 0.0510 - val_loss: 0.0043 - val_mae: 0.0403 - learning_rate: 0.0010
# Epoch 32/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0055 - mae: 0.0507 - val_loss: 0.0043 - val_mae: 0.0396 - learning_rate: 0.0010
# Epoch 33/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0054 - mae: 0.0505 - val_loss: 0.0043 - val_mae: 0.0396 - learning_rate: 0.0010
# Epoch 34/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0054 - mae: 0.0504 - val_loss: 0.0043 - val_mae: 0.0405 - learning_rate: 0.0010
# Epoch 35/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0054 - mae: 0.0503 - val_loss: 0.0042 - val_mae: 0.0395 - learning_rate: 0.0010
# Epoch 36/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0054 - mae: 0.0502 - val_loss: 0.0043 - val_mae: 0.0411 - learning_rate: 0.0010
# Epoch 37/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0054 - mae: 0.0501 - val_loss: 0.0042 - val_mae: 0.0397 - learning_rate: 0.0010
# Epoch 38/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0054 - mae: 0.0501 - val_loss: 0.0042 - val_mae: 0.0398 - learning_rate: 0.0010
# Epoch 39/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0053 - mae: 0.0500 - val_loss: 0.0042 - val_mae: 0.0396 - learning_rate: 0.0010
# Epoch 40/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0053 - mae: 0.0499 - val_loss: 0.0042 - val_mae: 0.0393 - learning_rate: 0.0010
# Epoch 41/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0053 - mae: 0.0499 - val_loss: 0.0041 - val_mae: 0.0389 - learning_rate: 0.0010
# Epoch 42/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0053 - mae: 0.0498 - val_loss: 0.0041 - val_mae: 0.0392 - learning_rate: 0.0010
# Epoch 43/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0053 - mae: 0.0498 - val_loss: 0.0043 - val_mae: 0.0408 - learning_rate: 0.0010
# Epoch 44/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0053 - mae: 0.0498 - val_loss: 0.0042 - val_mae: 0.0397 - learning_rate: 0.0010
# Epoch 45/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0053 - mae: 0.0496 - val_loss: 0.0042 - val_mae: 0.0406 - learning_rate: 0.0010
# Epoch 46/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0053 - mae: 0.0497 - val_loss: 0.0041 - val_mae: 0.0398 - learning_rate: 0.0010
# Epoch 47/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0052 - mae: 0.0495 - val_loss: 0.0042 - val_mae: 0.0402 - learning_rate: 0.0010
# Epoch 48/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0052 - mae: 0.0495 - val_loss: 0.0041 - val_mae: 0.0393 - learning_rate: 0.0010
# Epoch 49/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0052 - mae: 0.0494 - val_loss: 0.0042 - val_mae: 0.0399 - learning_rate: 0.0010
# Epoch 50/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0052 - mae: 0.0494 - val_loss: 0.0041 - val_mae: 0.0390 - learning_rate: 0.0010
# Epoch 51/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0052 - mae: 0.0493 - val_loss: 0.0041 - val_mae: 0.0396 - learning_rate: 0.0010
# Epoch 52/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0051 - mae: 0.0487 - val_loss: 0.0040 - val_mae: 0.0380 - learning_rate: 1.0000e-04
# Epoch 53/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0051 - mae: 0.0486 - val_loss: 0.0040 - val_mae: 0.0382 - learning_rate: 1.0000e-04
# Epoch 54/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0051 - mae: 0.0485 - val_loss: 0.0040 - val_mae: 0.0382 - learning_rate: 1.0000e-04
# Epoch 55/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0051 - mae: 0.0485 - val_loss: 0.0040 - val_mae: 0.0381 - learning_rate: 1.0000e-04
# Epoch 56/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0051 - mae: 0.0486 - val_loss: 0.0040 - val_mae: 0.0383 - learning_rate: 1.0000e-04
# Epoch 57/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0051 - mae: 0.0485 - val_loss: 0.0039 - val_mae: 0.0380 - learning_rate: 1.0000e-04
# Epoch 58/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 82s 36ms/step - loss: 0.0051 - mae: 0.0485 - val_loss: 0.0040 - val_mae: 0.0381 - learning_rate: 1.0000e-04
# Epoch 59/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0051 - mae: 0.0485 - val_loss: 0.0039 - val_mae: 0.0379 - learning_rate: 1.0000e-04
# Epoch 60/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0051 - mae: 0.0483 - val_loss: 0.0040 - val_mae: 0.0383 - learning_rate: 1.0000e-04
# Epoch 61/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0051 - mae: 0.0484 - val_loss: 0.0040 - val_mae: 0.0381 - learning_rate: 1.0000e-04
# Epoch 62/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0051 - mae: 0.0484 - val_loss: 0.0039 - val_mae: 0.0381 - learning_rate: 1.0000e-04
# Epoch 63/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0050 - mae: 0.0484 - val_loss: 0.0039 - val_mae: 0.0379 - learning_rate: 1.0000e-05
# Epoch 64/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0050 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0379 - learning_rate: 1.0000e-05
# Epoch 65/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 66/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0051 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0379 - learning_rate: 1.0000e-05
# Epoch 67/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0051 - mae: 0.0484 - val_loss: 0.0039 - val_mae: 0.0379 - learning_rate: 1.0000e-05
# Epoch 68/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 37ms/step - loss: 0.0050 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 69/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 37ms/step - loss: 0.0051 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0379 - learning_rate: 1.0000e-05
# Epoch 70/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0051 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 71/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0051 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0379 - learning_rate: 1.0000e-05
# Epoch 72/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0050 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0379 - learning_rate: 1.0000e-05
# Epoch 73/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0051 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0379 - learning_rate: 1.0000e-05
# Epoch 74/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0051 - mae: 0.0484 - val_loss: 0.0039 - val_mae: 0.0379 - learning_rate: 1.0000e-05
# Epoch 75/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0051 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0379 - learning_rate: 1.0000e-05
# Epoch 76/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0050 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0379 - learning_rate: 1.0000e-05
# Epoch 77/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 37ms/step - loss: 0.0050 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0379 - learning_rate: 1.0000e-05
# Epoch 78/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0051 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0379 - learning_rate: 1.0000e-05
# Epoch 79/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 37ms/step - loss: 0.0051 - mae: 0.0484 - val_loss: 0.0039 - val_mae: 0.0379 - learning_rate: 1.0000e-05
# Epoch 80/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0050 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0379 - learning_rate: 1.0000e-05
# Epoch 81/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 82s 36ms/step - loss: 0.0051 - mae: 0.0484 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 82/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0050 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0379 - learning_rate: 1.0000e-05
# Epoch 83/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0051 - mae: 0.0484 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 84/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0050 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 85/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0380 - learning_rate: 1.0000e-05
# Epoch 86/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0051 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0379 - learning_rate: 1.0000e-05
# Epoch 87/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0050 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 88/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0050 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0379 - learning_rate: 1.0000e-05
# Epoch 89/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0051 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0379 - learning_rate: 1.0000e-05
# Epoch 90/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0050 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 91/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0051 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0379 - learning_rate: 1.0000e-05
# Epoch 92/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 93/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 94/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0050 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0379 - learning_rate: 1.0000e-05
# Epoch 95/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0050 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0379 - learning_rate: 1.0000e-05
# Epoch 96/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0051 - mae: 0.0484 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 97/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0050 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0379 - learning_rate: 1.0000e-05
# Epoch 98/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0050 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 99/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0050 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0379 - learning_rate: 1.0000e-05
# Epoch 100/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0050 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0379 - learning_rate: 1.0000e-05
# Epoch 101/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 102/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0050 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0379 - learning_rate: 1.0000e-05
# Epoch 103/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0050 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0379 - learning_rate: 1.0000e-05
# Epoch 104/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0051 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0379 - learning_rate: 1.0000e-05
# Epoch 105/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 106/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 107/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0050 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 108/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0050 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 109/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0050 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 110/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0050 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0379 - learning_rate: 1.0000e-05
# Epoch 111/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 82s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 112/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0379 - learning_rate: 1.0000e-05
# Epoch 113/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0051 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0379 - learning_rate: 1.0000e-05
# Epoch 114/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0050 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0379 - learning_rate: 1.0000e-05
# Epoch 115/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0051 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0379 - learning_rate: 1.0000e-05
# Epoch 116/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 117/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 118/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0379 - learning_rate: 1.0000e-05
# Epoch 119/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 120/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 121/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0379 - learning_rate: 1.0000e-05
# Epoch 122/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 123/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 124/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 125/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 82s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0379 - learning_rate: 1.0000e-05
# Epoch 126/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 127/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0379 - learning_rate: 1.0000e-05
# Epoch 128/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0379 - learning_rate: 1.0000e-05
# Epoch 129/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 130/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 131/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 132/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 133/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0379 - learning_rate: 1.0000e-05
# Epoch 134/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0379 - learning_rate: 1.0000e-05
# Epoch 135/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0377 - learning_rate: 1.0000e-05
# Epoch 136/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 137/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 138/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 139/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 140/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0379 - learning_rate: 1.0000e-05
# Epoch 141/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0379 - learning_rate: 1.0000e-05
# Epoch 142/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 143/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0379 - learning_rate: 1.0000e-05
# Epoch 144/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 145/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 146/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 147/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 148/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 149/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 150/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 151/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 152/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 153/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 154/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0379 - learning_rate: 1.0000e-05
# Epoch 155/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 156/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 157/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 82s 36ms/step - loss: 0.0050 - mae: 0.0481 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 158/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 159/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 82s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 160/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0379 - learning_rate: 1.0000e-05
# Epoch 161/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0377 - learning_rate: 1.0000e-05
# Epoch 162/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 163/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 164/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0481 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 165/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 55s 36ms/step - loss: 0.0050 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 166/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 167/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 82s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0377 - learning_rate: 1.0000e-05
# Epoch 168/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 169/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 170/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 82s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 171/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 172/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 173/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0379 - learning_rate: 1.0000e-05
# Epoch 174/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 175/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 176/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0377 - learning_rate: 1.0000e-05
# Epoch 177/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 178/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 179/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 82s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 180/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0377 - learning_rate: 1.0000e-05
# Epoch 181/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0377 - learning_rate: 1.0000e-05
# Epoch 182/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0379 - learning_rate: 1.0000e-05
# Epoch 183/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0377 - learning_rate: 1.0000e-05
# Epoch 184/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0377 - learning_rate: 1.0000e-05
# Epoch 185/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0377 - learning_rate: 1.0000e-05
# Epoch 186/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0377 - learning_rate: 1.0000e-05
# Epoch 187/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 188/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 189/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 190/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 191/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 192/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 193/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0377 - learning_rate: 1.0000e-05
# Epoch 194/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0377 - learning_rate: 1.0000e-05
# Epoch 195/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 196/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 82s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 197/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 198/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 199/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 200/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0377 - learning_rate: 1.0000e-05
# Epoch 201/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 82s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 202/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0377 - learning_rate: 1.0000e-05
# Epoch 203/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0377 - learning_rate: 1.0000e-05
# Epoch 204/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 205/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0377 - learning_rate: 1.0000e-05
# Epoch 206/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 207/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0481 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 208/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0481 - val_loss: 0.0039 - val_mae: 0.0377 - learning_rate: 1.0000e-05
# Epoch 209/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0481 - val_loss: 0.0039 - val_mae: 0.0377 - learning_rate: 1.0000e-05
# Epoch 210/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 82s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 211/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 212/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 213/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0377 - learning_rate: 1.0000e-05
# Epoch 214/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 215/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0481 - val_loss: 0.0039 - val_mae: 0.0377 - learning_rate: 1.0000e-05
# Epoch 216/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0377 - learning_rate: 1.0000e-05
# Epoch 217/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0377 - learning_rate: 1.0000e-05
# Epoch 218/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0377 - learning_rate: 1.0000e-05
# Epoch 219/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0377 - learning_rate: 1.0000e-05
# Epoch 220/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0377 - learning_rate: 1.0000e-05
# Epoch 221/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0481 - val_loss: 0.0039 - val_mae: 0.0377 - learning_rate: 1.0000e-05
# Epoch 222/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0481 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 223/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0377 - learning_rate: 1.0000e-05
# Epoch 224/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0377 - learning_rate: 1.0000e-05
# Epoch 225/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 35ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0377 - learning_rate: 1.0000e-05
# Epoch 226/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0376 - learning_rate: 1.0000e-05
# Epoch 227/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0481 - val_loss: 0.0039 - val_mae: 0.0377 - learning_rate: 1.0000e-05
# Epoch 228/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 229/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0377 - learning_rate: 1.0000e-05
# Epoch 230/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0377 - learning_rate: 1.0000e-05
# Epoch 231/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0377 - learning_rate: 1.0000e-05
# Epoch 232/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0481 - val_loss: 0.0039 - val_mae: 0.0377 - learning_rate: 1.0000e-05
# Epoch 233/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 234/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0481 - val_loss: 0.0039 - val_mae: 0.0377 - learning_rate: 1.0000e-05
# Epoch 235/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0377 - learning_rate: 1.0000e-05
# Epoch 236/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0377 - learning_rate: 1.0000e-05
# Epoch 237/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0481 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 238/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0481 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 239/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0481 - val_loss: 0.0039 - val_mae: 0.0377 - learning_rate: 1.0000e-05
# Epoch 240/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 35ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0377 - learning_rate: 1.0000e-05
# Epoch 241/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0480 - val_loss: 0.0039 - val_mae: 0.0377 - learning_rate: 1.0000e-05
# Epoch 242/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0481 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 243/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0481 - val_loss: 0.0039 - val_mae: 0.0377 - learning_rate: 1.0000e-05
# Epoch 244/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0480 - val_loss: 0.0039 - val_mae: 0.0377 - learning_rate: 1.0000e-05
# Epoch 245/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0480 - val_loss: 0.0039 - val_mae: 0.0378 - learning_rate: 1.0000e-05
# Epoch 246/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0481 - val_loss: 0.0039 - val_mae: 0.0377 - learning_rate: 1.0000e-05
# Epoch 247/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0377 - learning_rate: 1.0000e-05
# Epoch 248/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0481 - val_loss: 0.0039 - val_mae: 0.0377 - learning_rate: 1.0000e-05
# Epoch 249/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0481 - val_loss: 0.0039 - val_mae: 0.0377 - learning_rate: 1.0000e-05
# Epoch 250/250
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - loss: 0.0050 - mae: 0.0482 - val_loss: 0.0039 - val_mae: 0.0377 - learning_rate: 1.0000e-05

# %%
best_epoch = np.argmin(history['val_loss'])
plt.figure(figsize=(17,4))
plt.plot(history['loss'], label='Training loss', alpha=.8, color='#ff7f0e')
plt.plot(history['val_loss'], label='Validation loss', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Mean Squared Error')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=(18,3))
plt.plot(history['learning_rate'], label='Learning Rate', alpha=.8, color='#ff7f0e')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.legend()
plt.grid(alpha=.3)
plt.show()

# %%
model.save(MODEL_NAME+".keras")

# %%
del model

# %%
model = tfk.models.load_model(MODEL_NAME+".keras")

# %%
X_test_reg, y_test_reg = build_sequences(False,window, stride, telescope)
X_test_reg.shape, y_test_reg.shape
# Out:
# ((103699, 200), (103699, 18))

# %%
# Autoregressive Forecasting
X_test_reg = np.expand_dims(X_test_reg, axis=-1)

reg_predictions = np.array([])
X_temp = X_test_reg
for reg in range(0,telescope,autoregressive_telescope):
    pred_temp = model.predict(X_temp,verbose=0)
    if(len(reg_predictions)==0):
        reg_predictions = pred_temp
    else:
        reg_predictions = np.concatenate((reg_predictions,pred_temp),axis=1)
    pred_temp = np.expand_dims(pred_temp, axis=-1)
    X_temp = np.concatenate((X_temp[:,autoregressive_telescope:],pred_temp), axis=1)

# %%
# Print the shape of the predictions
print(f"Predictions shape: {reg_predictions.shape}")

# Calculate and print Mean Squared Error (MSE)
mean_squared_error = tfk.metrics.mean_squared_error(y_test_reg.flatten(), reg_predictions.flatten()).numpy()
print(f"Mean Squared Error: {mean_squared_error}")

# Calculate and print Mean Absolute Error (MAE)
mean_absolute_error = tfk.metrics.mean_absolute_error(y_test_reg.flatten(), reg_predictions.flatten()).numpy()
print(f"Mean Absolute Error: {mean_absolute_error}")
# Out:
# Predictions shape: (103699, 18)
# Mean Squared Error: 0.00966314785182476
# Mean Absolute Error: 0.06606149673461914
